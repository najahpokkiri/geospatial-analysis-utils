# %%
import pandas as pd
import geopandas as gpd
import rasterio as rio
from rasterio import plot
import rioxarray as rxr
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
os.chdir('/Users/najah/work/internships/meghna')

# %%
indices = pd.read_csv('./LT05_L1TP_145044_20100428_20161016_01_T1/145044_20100428_indices/random_points_indices_data.csv')

# %%
ndvi = rio.open('./LT05_L1TP_145044_20100428_20161016_01_T1/145044_20100428_indices/145044_20100428_ndvi')

# %%
plot.show(ndvi.read(1), with_bounds= False)
# Out:
# <AxesSubplot:>

# %%
plt.imshow(ndvi.read(1),  cmap=plt.cm.summer)
plt.show()
