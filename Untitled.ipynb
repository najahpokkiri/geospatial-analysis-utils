# %%
import ee
import geemap
import pandas as pd
import numpy as np
import os
import geopandas as gpd

# %%
ee.Authenticate()
ee.Initialize()
os.chdir('/Users/najah/work/internships/meghna//LT05_L1TP_145044_20100428_20161016_01_T1')

# %%
training_data.head()
# Out:
#    Unnamed: 0  geometry        B1        B2        B3        B4        B5  \
# 0           0       NaN  0.155519  0.174203  0.202183  0.248888  0.293284
# 1           1       NaN  0.134694  0.139385  0.157736  0.213023  0.224479
# 2           2       NaN  0.131917  0.127779  0.142920  0.192103  0.238644
# 3           3       NaN  0.147189  0.153892  0.177490  0.216012  0.271023
# 4           4       NaN  0.143024  0.150991  0.155267  0.251877  0.266976
#
#          B7      baiml      baims  class  elev      gemi     mirbi       nbr  \
# 0  0.249197  25.282782  25.289064     16   519  0.370494  1.617788 -0.000620
# 1  0.162116  37.628448  37.627612     11   587  0.388486  1.421267  0.135703
# 2  0.181779  49.522112  49.523274     11   501  0.384330  1.479077  0.027611
# 3  0.215488  36.284659  36.289463     11   379  0.373888  1.498853  0.001215
# 4  0.184588  24.537611  24.541859     11   509  0.417057  1.229519  0.154166
#
#        ndmi      ndvi      ndwi  shadow     slope
# ...

# %%
training_data = pd.read_csv("./145044_20100428_models/training_data.csv")


training = geemap.(training_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 4>()
#       1 training_data = pd.read_csv("./145044_20100428_models/training_data.csv")
# ----> 4 training = geemap.csv_to_ee(training_data)
#
# File ~/miniforge3/envs/ee/lib/python3.9/site-packages/geemap/common.py:1158, in csv_to_ee(in_csv, latitude, longitude, encoding, geodesic)
#    1142 def csv_to_ee(
#    1143     in_csv, latitude="latitude", longitude="longitude", encoding="utf-8", geodesic=True
#    1144 ):
#    1145     """Creates points for a CSV file and exports data as a GeoJSON.
#    1146
#    1147     Args:
#    (...)
#    1155         ee_object: An ee.Geometry object
#    1156     """
# -> 1158     geojson = csv_to_geojson(
#    1159         in_csv, latitude=latitude, longitude=longitude, encoding=encoding
#    1160     )
#    1161     fc = geojson_to_ee(geojson, geodesic=geodesic)
# ...

# %%
image = ee.Image('LANDSAT/LT05/C01/T1_TOA/LT05_145044_20100428') 
# Use these bands for prediction.
bands = ['B1', 'B2', 'B3', 'B4', 'B5',  'B7', 'ndvi','ndmi' ,'nbr', 'ndwi',  'mirbi', 'baims', 'baiml', 'gemi','slope', 'elev', 'shadow']

# This property of the table stores the land cover labels.
label = 'class'
